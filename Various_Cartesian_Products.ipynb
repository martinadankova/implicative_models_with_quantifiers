# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# import os
# os.chdir('/content/drive/MyDrive/Colab Notebooks')
import os
# Verify the change
print("Current Working Directory: ", os.getcwd())

from definitions import quantifiers as qt
import numpy as np
import matplotlib.pyplot as plt
from definitions import FuzzyRelations as fr
from definitions import FuzzyRelations as sim
import pandas as pd
import matplotlib.pyplot as plt
from definitions import models as md
# Out:
# Current Working Directory:  d:\Documents\Python\Implikative_models_with_quantifiers

# %%
from definitions import FuzzyRelations

from importlib import reload  # Python 3.4+
FuzzyRelations = reload(FuzzyRelations)

disx=1000
minx=0
maxx=15
x=[minx+k*((maxx-minx)/disx) for k in range(0,disx)]
y=x
Ax=fr.finterval(x,3.5,5.5,0.7)
By=fr.finterval(y,5,7,0.8)
A2x=fr.finterval(x,4.5,6.5,0.7)
B2y=fr.finterval(y,11,12,0.8)
B3y=fr.finterval(y,7.5,10,0.5)
negA=fr.negSet(Ax)
negB=fr.negSet(By)

CartAB=fr.CartP(Ax,By)
CartLAB=fr.CartL(Ax,By)
CartMAB=fr.CartM(Ax,By)

CartPA2B2=fr.CartP(A2x,B2y)
CartLA2B2=fr.CartL(A2x,B2y)
CartMA2B2=fr.CartM(A2x,B2y)

CartPAB2=fr.CartP(Ax,B2y)
CartLAB2=fr.CartL(Ax,B2y)
CartMAB2=fr.CartM(Ax,B2y)

CartPAnB=fr.CartP(Ax,negB)
CartLAnB=fr.CartL(Ax,negB)
CartMAnB=fr.CartM(Ax,negB)

CartPnAB=fr.CartP(negA,By)
CartLnAB=fr.CartL(negA,By)
CartMnAB=fr.CartM(negA,By)

CartPnAnB=fr.CartP(negA,negB)
CartLnAnB=fr.CartL(negA,negB)
CartMnAnB=fr.CartM(negA,negB)

modelMProd=np.maximum(CartAB,CartPAB2)
modelMLuk=np.maximum(CartLAB,CartLAB2)
modelMMin=np.maximum(CartMAB,CartMAB2)

plt.plot(x,Ax, linewidth=3, label='A')
plt.plot(y,By, linewidth=3, linestyle='--', label='B')

#plt.plot(x,A2x, linewidth=3, linestyle=':', label='A2')
# Plotting the data with star markers
plt.plot(y, B2y, linewidth=3, linestyle='None', marker='*', markersize=10, label='B2')
plt.grid(axis='x', color='0.95')
plt.plot(y, B3y, linewidth=3, linestyle='None', marker='*', markersize=10, label='B3')
plt.grid(axis='x', color='0.85')
plt.legend(title='Fuzzy sets:')
plt.show()

# plt.imshow(modelMProd, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(modelMLuk, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(modelMMin, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(CartLAB, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(CartLAnB, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(CartLnAB, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

# plt.imshow(CartLnAnB, cmap='viridis', interpolation='nearest')
# plt.colorbar()
# plt.show()

b1=1
b2=1
b3=0
LB1=fr.conjL(b1,By)
LB2=fr.conjL(b2,B2y)
PB1=fr.conjP(b1,By)
PB2=fr.conjP(b2,B2y)
LB3=fr.conjL(b3,B3y)
PB3=fr.conjP(b3,B3y)
BvB2=np.maximum(By,B2y)
LB1vB2=np.maximum(LB1,LB2)
PB1vB2=np.maximum(PB1,PB2)
LB3vB12=np.maximum(LB1vB2,LB3)
PB3vB12=np.maximum(PB1vB2,PB3)

wAxB12_L=fr.CartL(Ax,LB1vB2)
wAxB12_P=fr.CartP(Ax,PB1vB2)

Wmodel2IProd=fr.CartImplP(Ax,PB1vB2)
Wmodel2ILuk=fr.CartImplL(Ax,LB1vB2)

Wmodel3IProd=fr.CartImplP(Ax,PB3vB12)
Wmodel3ILuk=fr.CartImplL(Ax,LB3vB12)
plt.imshow(Wmodel3ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel3IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

AxB_L=fr.CartL(Ax,By)
AxB_P=fr.CartP(Ax,By)
AimplB_L=fr.CartImplL(Ax,By)
AimplB_P=fr.CartImplP(Ax,By)
A2implB2_L=fr.CartImplL(A2x,B2y)
A2implB2_P=fr.CartImplP(A2x,B2y)
AimplB2_L=fr.CartImplL(Ax,B2y)
AimplB2_P=fr.CartImplP(Ax,B2y)

model2IProd=fr.CartImplP(Ax,BvB2)
model2ILuk=fr.CartImplL(Ax,BvB2)


model1IProd=np.minimum(AimplB2_P,AimplB_P)
model1ILuk=np.minimum(AimplB2_L,AimplB_L)

modelIProd=np.minimum(A2implB2_P,AimplB_P)
modelILuk=np.minimum(A2implB2_L,AimplB_L)

plt.imshow(model2ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(model2IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()


plt.imshow(model1ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(model1IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(modelILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(modelIProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

dif_L=np.subtract(AimplB_L,AxB_L)
dif_P=np.subtract(AimplB_P,AxB_P)

plt.imshow(AxB_L, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(AxB_P, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(AimplB_L, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(AimplB_P, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(dif_L, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(dif_P, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel2ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel2IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(wAxB12_L, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(wAxB12_P, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()
# Out:
# d:\Documents\Python\Implikative_models_with_quantifiers\definitions\FuzzyRelations.py:16: RuntimeWarning: divide by zero encountered in divide
#   outf=np.where(x<=y,1,y/x)
# d:\Documents\Python\Implikative_models_with_quantifiers\definitions\FuzzyRelations.py:16: RuntimeWarning: invalid value encountered in divide
#   outf=np.where(x<=y,1,y/x)

# %%
b1=1
b2=1
LB1=fr.conjL(b1,By)
LB2=fr.conjL(b2,B2y)
PB1=fr.conjP(b1,By)
PB2=fr.conjP(b2,B2y)
BvB2=np.maximum(By,B2y)
LB1vB2=np.maximum(LB1,LB2)
PB1vB2=np.maximum(PB1,PB2)

wAxB12_L=fr.CartL(Ax,LB1vB2)
wAxB12_P=fr.CartP(Ax,PB1vB2)
plt.imshow(Wmodel2ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel2IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

b1=0.8
b2=0.5
LB1=fr.conjL(b1,By)
LB2=fr.conjL(b2,B2y)
PB1=fr.conjP(b1,By)
PB2=fr.conjP(b2,B2y)
BvB2=np.maximum(By,B2y)
LB1vB2=np.maximum(LB1,LB2)
PB1vB2=np.maximum(PB1,PB2)

wAxB12_L=fr.CartL(Ax,LB1vB2)
wAxB12_P=fr.CartP(Ax,PB1vB2)
plt.imshow(Wmodel2ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel2IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

b1=0.8
b2=0
LB1=fr.conjL(b1,By)
LB2=fr.conjL(b2,B2y)
PB1=fr.conjP(b1,By)
PB2=fr.conjP(b2,B2y)
BvB2=np.maximum(By,B2y)
LB1vB2=np.maximum(LB1,LB2)
PB1vB2=np.maximum(PB1,PB2)

wAxB12_L=fr.CartL(Ax,LB1vB2)
wAxB12_P=fr.CartP(Ax,PB1vB2)
plt.imshow(Wmodel2ILuk, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(Wmodel2IProd, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()
